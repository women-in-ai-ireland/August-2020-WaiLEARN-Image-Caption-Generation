# %% [markdown]
# <a href="https://colab.research.google.com/github/royn5618/August-2020-WaiLEARN-Image-Caption-Generation/blob/master/Visualizing_Filters_and_Featue_Maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.applications.vgg16 import VGG16
# load the model
model = VGG16()
# summarize the model
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_10 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# input_10
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool
# flatten
# fc1
# fc2
# predictions

# %%
for layer in model.layers[1:]:
  print(layer.name)
  filters, biases =layer.get_weights()
  print(filters.shape)
  print(filters)
  print('-----')
  print(biases)
  print('-----')
  break
# Out:
# block1_conv1
# (3, 3, 3, 64)
# [[[[ 4.29470569e-01  1.17273867e-01  3.40129584e-02 ... -1.32241577e-01
#     -5.33475243e-02  7.57738389e-03]
#    [ 5.50379455e-01  2.08774377e-02  9.88311544e-02 ... -8.48205537e-02
#     -5.11389151e-02  3.74943428e-02]
#    [ 4.80015397e-01 -1.72696680e-01  3.75577137e-02 ... -1.27135560e-01
#     -5.02991639e-02  3.48965675e-02]]
#
#   [[ 3.73466998e-01  1.62062630e-01  1.70863140e-03 ... -1.48207128e-01
#     -2.35300660e-01 -6.30356818e-02]
#    [ 4.40074533e-01  4.73412387e-02  5.13819456e-02 ... -9.88498852e-02
#     -2.96195745e-01 -7.04357103e-02]
#    [ 4.08547401e-01 -1.70375049e-01 -4.96297423e-03 ... -1.22360572e-01
#     -2.76450396e-01 -3.90796512e-02]]
#
#   [[-6.13601133e-02  1.35693997e-01 -1.15694344e-01 ... -1.40158370e-01
#     -3.77666801e-01 -3.00509870e-01]
#    [-8.13870355e-02  4.18543853e-02 -1.01763301e-01 ... -9.43124294e-02
#     -5.05662560e-01 -3.83694321e-01]
# ...

# %%
for layer in model.layers:
  if 'conv' not in layer.name:
    continue
  filters, biases =layer.get_weights()
  print('{} : {}'.format(layer.name, filters.shape))
# Out:
# block1_conv1 : (3, 3, 3, 64)
# block1_conv2 : (3, 3, 64, 64)
# block2_conv1 : (3, 3, 64, 128)
# block2_conv2 : (3, 3, 128, 128)
# block3_conv1 : (3, 3, 128, 256)
# block3_conv2 : (3, 3, 256, 256)
# block3_conv3 : (3, 3, 256, 256)
# block4_conv1 : (3, 3, 256, 512)
# block4_conv2 : (3, 3, 512, 512)
# block4_conv3 : (3, 3, 512, 512)
# block5_conv1 : (3, 3, 512, 512)
# block5_conv2 : (3, 3, 512, 512)
# block5_conv3 : (3, 3, 512, 512)

# %%
from keras.applications import ResNet50, ResNet152V2, InceptionResNetV2
# load the model
model_resnet_50 = ResNet50()
model_resnet_152_v2 = ResNet152V2()
model_inception_resnet_v2 = InceptionResNetV2()

# %%
def list_layer_names(model):
  for layer in model.layers:
    print(layer.name)

# %%
def list_model_features(model):
  for layer in model.layers:
    if '_conv' in layer.name:
      print(layer.name)
      filters, biases =layer.get_weights()
      print('{} : {}'.format(layer.name, filters.shape))

# %%
list_layer_names(model_resnet_50)
# Out:
# input_11
# conv1_pad
# conv1_conv
# conv1_bn
# conv1_relu
# pool1_pad
# pool1_pool
# conv2_block1_1_conv
# conv2_block1_1_bn
# conv2_block1_1_relu
# conv2_block1_2_conv
# conv2_block1_2_bn
# conv2_block1_2_relu
# conv2_block1_0_conv
# conv2_block1_3_conv
# conv2_block1_0_bn
# conv2_block1_3_bn
# conv2_block1_add
# conv2_block1_out
# conv2_block2_1_conv
# conv2_block2_1_bn
# conv2_block2_1_relu
# conv2_block2_2_conv
# conv2_block2_2_bn
# conv2_block2_2_relu
# conv2_block2_3_conv
# conv2_block2_3_bn
# conv2_block2_add
# conv2_block2_out
# conv2_block3_1_conv
# conv2_block3_1_bn
# conv2_block3_1_relu
# conv2_block3_2_conv
# conv2_block3_2_bn
# conv2_block3_2_relu
# conv2_block3_3_conv
# conv2_block3_3_bn
# conv2_block3_add
# conv2_block3_out
# conv3_block1_1_conv
# conv3_block1_1_bn
# conv3_block1_1_relu
# conv3_block1_2_conv
# conv3_block1_2_bn
# conv3_block1_2_relu
# conv3_block1_0_conv
# conv3_block1_3_conv
# conv3_block1_0_bn
# conv3_block1_3_bn
# conv3_block1_add
# ...

# %%
list_model_features(model_resnet_50)
# Out:
# conv1_conv
# conv1_conv : (7, 7, 3, 64)
# conv2_block1_1_conv
# conv2_block1_1_conv : (1, 1, 64, 64)
# conv2_block1_2_conv
# conv2_block1_2_conv : (3, 3, 64, 64)
# conv2_block1_0_conv
# conv2_block1_0_conv : (1, 1, 64, 256)
# conv2_block1_3_conv
# conv2_block1_3_conv : (1, 1, 64, 256)
# conv2_block2_1_conv
# conv2_block2_1_conv : (1, 1, 256, 64)
# conv2_block2_2_conv
# conv2_block2_2_conv : (3, 3, 64, 64)
# conv2_block2_3_conv
# conv2_block2_3_conv : (1, 1, 64, 256)
# conv2_block3_1_conv
# conv2_block3_1_conv : (1, 1, 256, 64)
# conv2_block3_2_conv
# conv2_block3_2_conv : (3, 3, 64, 64)
# conv2_block3_3_conv
# conv2_block3_3_conv : (1, 1, 64, 256)
# conv3_block1_1_conv
# conv3_block1_1_conv : (1, 1, 256, 128)
# conv3_block1_2_conv
# conv3_block1_2_conv : (3, 3, 128, 128)
# conv3_block1_0_conv
# conv3_block1_0_conv : (1, 1, 256, 512)
# conv3_block1_3_conv
# conv3_block1_3_conv : (1, 1, 128, 512)
# conv3_block2_1_conv
# conv3_block2_1_conv : (1, 1, 512, 128)
# conv3_block2_2_conv
# ...

# %%
filters, biases = model.layers[1].get_weights()

# %%
filters.shape
# Out:
# (3, 3, 3, 64)

# %%
model.name
# Out:
# 'vgg16'

# %%
model.weights[0]
# Out:
# <tf.Variable 'block1_conv1/kernel:0' shape=(3, 3, 3, 64) dtype=float32, numpy=
# array([[[[ 4.29470569e-01,  1.17273867e-01,  3.40129584e-02, ...,
#           -1.32241577e-01, -5.33475243e-02,  7.57738389e-03],
#          [ 5.50379455e-01,  2.08774377e-02,  9.88311544e-02, ...,
#           -8.48205537e-02, -5.11389151e-02,  3.74943428e-02],
#          [ 4.80015397e-01, -1.72696680e-01,  3.75577137e-02, ...,
#           -1.27135560e-01, -5.02991639e-02,  3.48965675e-02]],
#
#         [[ 3.73466998e-01,  1.62062630e-01,  1.70863140e-03, ...,
#           -1.48207128e-01, -2.35300660e-01, -6.30356818e-02],
#          [ 4.40074533e-01,  4.73412387e-02,  5.13819456e-02, ...,
#           -9.88498852e-02, -2.96195745e-01, -7.04357103e-02],
#          [ 4.08547401e-01, -1.70375049e-01, -4.96297423e-03, ...,
#           -1.22360572e-01, -2.76450396e-01, -3.90796512e-02]],
#
#         [[-6.13601133e-02,  1.35693997e-01, -1.15694344e-01, ...,
# ...

# %%
model.weights[1]
# Out:
# <tf.Variable 'block1_conv1/bias:0' shape=(64,) dtype=float32, numpy=
# array([ 0.73429835,  0.09340367,  0.06775674,  0.8862966 ,  0.25994542,
#         0.66426694, -0.01582893,  0.3249065 ,  0.68600726,  0.06247932,
#         0.58156496,  0.2361475 ,  0.69694996,  0.19451167,  0.4858922 ,
#         0.44571847,  0.5113422 ,  0.208576  ,  0.57557714,  0.33199573,
#         0.4997983 ,  0.7117759 ,  0.30284074,  0.7082712 ,  0.04548979,
#         0.7446502 ,  0.29845494,  0.48211655,  0.81658626,  0.62603897,
#         0.3768093 ,  2.064037  ,  0.77311045,  0.3459577 ,  0.6130958 ,
#         0.65459156,  0.39045632,  0.50869167,  0.2625384 ,  0.23669638,
#         0.07971057,  1.1179353 ,  0.26129362,  0.8697589 ,  0.21543622,
#         0.78007823,  0.37015367,  0.47993386,  0.4313978 ,  0.5084194 ,
#         0.23049663,  0.7636527 ,  0.35419866,  0.45794216,  0.4662595 ,
#         0.09850298,  0.3803252 ,  0.66880196,  0.4015123 ,  0.90510356,
# ...

# %%
model.variables[0]
# Out:
# <tf.Variable 'block1_conv1/kernel:0' shape=(3, 3, 3, 64) dtype=float32, numpy=
# array([[[[ 4.29470569e-01,  1.17273867e-01,  3.40129584e-02, ...,
#           -1.32241577e-01, -5.33475243e-02,  7.57738389e-03],
#          [ 5.50379455e-01,  2.08774377e-02,  9.88311544e-02, ...,
#           -8.48205537e-02, -5.11389151e-02,  3.74943428e-02],
#          [ 4.80015397e-01, -1.72696680e-01,  3.75577137e-02, ...,
#           -1.27135560e-01, -5.02991639e-02,  3.48965675e-02]],
#
#         [[ 3.73466998e-01,  1.62062630e-01,  1.70863140e-03, ...,
#           -1.48207128e-01, -2.35300660e-01, -6.30356818e-02],
#          [ 4.40074533e-01,  4.73412387e-02,  5.13819456e-02, ...,
#           -9.88498852e-02, -2.96195745e-01, -7.04357103e-02],
#          [ 4.08547401e-01, -1.70375049e-01, -4.96297423e-03, ...,
#           -1.22360572e-01, -2.76450396e-01, -3.90796512e-02]],
#
#         [[-6.13601133e-02,  1.35693997e-01, -1.15694344e-01, ...,
# ...

# %%
model.variables[1]
# Out:
# <tf.Variable 'block1_conv1/bias:0' shape=(64,) dtype=float32, numpy=
# array([ 0.73429835,  0.09340367,  0.06775674,  0.8862966 ,  0.25994542,
#         0.66426694, -0.01582893,  0.3249065 ,  0.68600726,  0.06247932,
#         0.58156496,  0.2361475 ,  0.69694996,  0.19451167,  0.4858922 ,
#         0.44571847,  0.5113422 ,  0.208576  ,  0.57557714,  0.33199573,
#         0.4997983 ,  0.7117759 ,  0.30284074,  0.7082712 ,  0.04548979,
#         0.7446502 ,  0.29845494,  0.48211655,  0.81658626,  0.62603897,
#         0.3768093 ,  2.064037  ,  0.77311045,  0.3459577 ,  0.6130958 ,
#         0.65459156,  0.39045632,  0.50869167,  0.2625384 ,  0.23669638,
#         0.07971057,  1.1179353 ,  0.26129362,  0.8697589 ,  0.21543622,
#         0.78007823,  0.37015367,  0.47993386,  0.4313978 ,  0.5084194 ,
#         0.23049663,  0.7636527 ,  0.35419866,  0.45794216,  0.4662595 ,
#         0.09850298,  0.3803252 ,  0.66880196,  0.4015123 ,  0.90510356,
# ...

# %%
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
filters
# Out:
# array([[[[0.8601116 , 0.6161919 , 0.55114007, ..., 0.4212452 ,
#           0.4828852 , 0.5304859 ],
#          [0.9545779 , 0.5408773 , 0.6017826 , ..., 0.4582953 ,
#           0.4846108 , 0.5538601 ],
#          [0.89960235, 0.3896376 , 0.5539096 , ..., 0.42523453,
#           0.4852669 , 0.5518304 ]],
#
#         [[0.81635594, 0.65118545, 0.52590066, ..., 0.4087713 ,
#           0.340725  , 0.47531587],
#          [0.8683965 , 0.5615535 , 0.5647105 , ..., 0.44733417,
#           0.2931476 , 0.46953422],
#          [0.8437643 , 0.39145148, 0.5206881 , ..., 0.42896524,
#           0.30857468, 0.4940327 ]],
#
#         [[0.47662497, 0.63058364, 0.43417358, ..., 0.4150598 ,
#           0.22949417, 0.28977698],
#          [0.4609779 , 0.5572666 , 0.4450579 , ..., 0.4508793 ,
#           0.12949093, 0.22478487],
#          [0.4736674 , 0.40397066, 0.41671643, ..., 0.42346177,
#           0.16341406, 0.27143562]]],
#
#
#        [[[0.7392438 , 0.6404719 , 0.6507926 , ..., 0.43525034,
# ...

# %%
## Breaking Down Each Filters

# %%
n_filters, ix = 6, 1
for i in range(n_filters):
  print(i)
  # get the filter
  f = filters[:, :, :, i]
  print(f.shape)
  print(f)
# Out:
# 0
# (3, 3, 3)
# [[[0.8601116  0.9545779  0.89960235]
#   [0.81635594 0.8683965  0.8437643 ]
#   [0.47662497 0.4609779  0.4736674 ]]
#
#  [[0.7392438  0.7946921  0.767142  ]
#   [0.55478704 0.55631167 0.5637889 ]
#   [0.23765364 0.17024457 0.20940173]]
#
#  [[0.47966576 0.47875416 0.48481962]
#   [0.31966972 0.2662131  0.3017171 ]
#   [0.25103468 0.145611   0.19757837]]]
# 1
# (3, 3, 3)
# [[[0.6161919  0.5408773  0.3896376 ]
#   [0.65118545 0.5615535  0.39145148]
#   [0.63058364 0.5572666  0.40397066]]
#
#  [[0.6404719  0.5488246  0.37799242]
#   [0.6826218  0.5759833  0.38582882]
#   [0.6508931  0.56070673 0.3883068 ]]
#
#  [[0.6256226  0.5493164  0.39486766]
#   [0.65861547 0.56731075 0.39434877]
#   [0.63294035 0.55763006 0.40186328]]]
# 2
# (3, 3, 3)
# [[[0.55114007 0.6017826  0.5539096 ]
#   [0.52590066 0.5647105  0.5206881 ]
#   [0.43417358 0.4450579  0.41671643]]
#
#  [[0.6507926  0.7126644  0.65472686]
#   [0.6467724  0.69669527 0.6426892 ]
# ...

# %%
import matplotlib.pyplot as plt
# plot first few filters
n_filters, ix = 6, 1
for i in range(n_filters):
  # print(i)
  # get the filter
  f = filters[:, :, :, i]
  # print(f.shape)
  # print(f)
  # plot each channel separately
  for j in range(3):
    print(f[:, :, j])
    # ax = plt.subplot(n_filters, 3, ix)
    plt.imshow(f[:, :, j], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    ix += 1
    print('---------------------------------')
    plt.show()
# Out:
# [[0.8601116  0.81635594 0.47662497]
#  [0.7392438  0.55478704 0.23765364]
#  [0.47966576 0.31966972 0.25103468]]
# ---------------------------------
# [[0.9545779  0.8683965  0.4609779 ]
#  [0.7946921  0.55631167 0.17024457]
#  [0.47875416 0.2662131  0.145611  ]]
# ---------------------------------
# [[0.89960235 0.8437643  0.4736674 ]
#  [0.767142   0.5637889  0.20940173]
#  [0.48481962 0.3017171  0.19757837]]
# ---------------------------------
# [[0.6161919  0.65118545 0.63058364]
#  [0.6404719  0.6826218  0.6508931 ]
#  [0.6256226  0.65861547 0.63294035]]
# ---------------------------------
# [[0.5408773  0.5615535  0.5572666 ]
#  [0.5488246  0.5759833  0.56070673]
#  [0.5493164  0.56731075 0.55763006]]
# ---------------------------------
# [[0.3896376  0.39145148 0.40397066]
#  [0.37799242 0.38582882 0.3883068 ]
#  [0.39486766 0.39434877 0.40186328]]
# ---------------------------------
# [[0.55114007 0.52590066 0.43417358]
#  [0.6507926  0.6467724  0.45429817]
# ...

# %%
import matplotlib.pyplot as plt
# plot first few filters
n_filters, ix = 6, 1
for i in range(n_filters):
  # print(i)
  # get the filter
  f = filters[:, :, :, i]
  # print(f.shape)
  # print(f)
  # plot each channel separately
  for j in range(3):
    # print(f[:, :, j])
    ax = plt.subplot(n_filters, 3, ix)
    plt.imshow(f[:, :, j], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    ix += 1
    # print('---------------------------------')
plt.show()

# %%
# !pip install -q kaggle
# !pip install -q kaggle-cli
# Upload the kaggle.json from Kaggle -> My Account -> Create New API Token
from google.colab import files
uploaded = files.upload()
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download hsankesara/flickr-image-dataset -p /dataset
# !unzip /dataset/*.zip
# Out:
#      |████████████████████████████████| 81kB 2.7MB/s
#      |████████████████████████████████| 5.3MB 8.0MB/s
#      |████████████████████████████████| 112kB 43.2MB/s
#      |████████████████████████████████| 51kB 5.2MB/s
#      |████████████████████████████████| 133kB 46.9MB/s
# ...
#      <input type="file" id="files-82887d93-03f1-420d-ac7e-24c228e28b4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82887d93-03f1-420d-ac7e-24c228e28b4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Streaming output truncated to the last 5000 lines.
#   inflating: flickr30k_images/flickr30k_images/flickr30k_images/535529555.jpg
#   inflating: flickr30k_images/flickr30k_images/flickr30k_images/5356236664.jpg
# ...

# %%
image_data_path = 'flickr30k_images/flickr30k_images/'
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
image_load = load_img(image_data_path + "2199200615.jpg")
plt.imshow(image_load)

# %%
dog_image_path = image_data_path + "2199200615.jpg"

# %%
# OUtput shapes
for i in range(len(model.layers)):
	layer = model.layers[i]
	# check for convolutional layer
	if 'conv' not in layer.name:
		continue
	print(i, layer.name, layer.output.shape)
# Out:
# 1 block1_conv1 (None, 224, 224, 64)
# 2 block1_conv2 (None, 224, 224, 64)
# 4 block2_conv1 (None, 112, 112, 128)
# 5 block2_conv2 (None, 112, 112, 128)
# 7 block3_conv1 (None, 56, 56, 256)
# 8 block3_conv2 (None, 56, 56, 256)
# 9 block3_conv3 (None, 56, 56, 256)
# 11 block4_conv1 (None, 28, 28, 512)
# 12 block4_conv2 (None, 28, 28, 512)
# 13 block4_conv3 (None, 28, 28, 512)
# 15 block5_conv1 (None, 14, 14, 512)
# 16 block5_conv2 (None, 14, 14, 512)
# 17 block5_conv3 (None, 14, 14, 512)

# %%
from keras.models import Model

model = Model(inputs=model.inputs, outputs=model.layers[1].output)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_10 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# ...
# Total params: 1,792
# Trainable params: 1,792
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import load_img,img_to_array
img = load_img(dog_image_path, target_size=(224, 224))
img = img_to_array(img)
img
# Out:
# array([[[219., 227., 229.],
#         [219., 221., 233.],
#         [202., 202., 210.],
#         ...,
#         [252., 254., 253.],
#         [230., 235., 231.],
#         [246., 245., 250.]],
#
#        [[226., 229., 236.],
#         [235., 233., 246.],
#         [212., 209., 220.],
#         ...,
#         [237., 241., 242.],
#         [229., 226., 233.],
#         [179., 189., 178.]],
#
#        [[223., 227., 230.],
#         [232., 231., 237.],
#         [201., 200., 205.],
#         ...,
#         [216., 220., 219.],
#         [215., 216., 221.],
#         [151., 173., 152.]],
#
#        ...,
#
#        [[ 86.,  94.,  53.],
#         [ 95., 102.,  60.],
#         [ 94., 101.,  59.],
#         ...,
#         [107., 107.,  69.],
#         [104., 113.,  70.],
#         [ 93.,  99.,  63.]],
#
#        [[ 85.,  93.,  52.],
#         [ 91.,  98.,  56.],
#         [ 92.,  99.,  57.],
#         ...,
#         [114., 112.,  74.],
#         [108., 115.,  73.],
# ...

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
from numpy import expand_dims
img = expand_dims(img, axis=0)
img
# Out:
# array([[[[219., 227., 229.],
#          [219., 221., 233.],
#          [202., 202., 210.],
#          ...,
#          [252., 254., 253.],
#          [230., 235., 231.],
#          [246., 245., 250.]],
#
#         [[226., 229., 236.],
#          [235., 233., 246.],
#          [212., 209., 220.],
#          ...,
#          [237., 241., 242.],
#          [229., 226., 233.],
#          [179., 189., 178.]],
#
#         [[223., 227., 230.],
#          [232., 231., 237.],
#          [201., 200., 205.],
#          ...,
#          [216., 220., 219.],
#          [215., 216., 221.],
#          [151., 173., 152.]],
#
#         ...,
#
#         [[ 86.,  94.,  53.],
#          [ 95., 102.,  60.],
#          [ 94., 101.,  59.],
#          ...,
#          [107., 107.,  69.],
#          [104., 113.,  70.],
#          [ 93.,  99.,  63.]],
#
#         [[ 85.,  93.,  52.],
#          [ 91.,  98.,  56.],
#          [ 92.,  99.,  57.],
#          ...,
#          [114., 112.,  74.],
# ...

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
from keras.applications.vgg16 import preprocess_input
img = preprocess_input(img)
img.shape
# Out:
# (1, 224, 224, 3)

# %%
feature_maps = model.predict(img)
square = 8
ix = 1
plt.figure(figsize=[20,20])
for _ in range(square):
  for _ in range(square):
    # specify subplot and turn of axis
    ax = plt.subplot(square, square, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    plt.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
    ix += 1
plt.show()

# %%
model.output.shape
# Out:
# TensorShape([None, 224, 224, 64])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_10 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# ...
# Total params: 1,792
# Trainable params: 1,792
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = VGG16()
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_15 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
ixs = [2, 5, 9, 13, 17]
outputs = [model.layers[i].output for i in ixs]
model = Model(inputs=model.inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_15 (InputLayer)        [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...
